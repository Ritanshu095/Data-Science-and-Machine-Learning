# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/tiwar/Desktop/NFL/NFL Play by Play 2009-2016 (v3).csv")
df.head()
# Out:
# C:\Users\tiwar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (25,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# ...

# %%
df.shape
# Out:
# (362447, 102)

# %%
##Counting missing values 
count_missing_values = df.isnull().sum()
count_missing_values[0:15] # See data of first 15 columns
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            54218
# time              188
# TimeUnder           0
# TimeSecs          188
# PlayTimeDiff      374
# SideofField       450
# yrdln             723
# yrdline100        723
# ydstogo             0
# ydsnet              0
# GoalToGo          723
# dtype: int64

# %%
## It is always a good practice to know how much percentage of data is missing.

total_no_of_cells = np.product(df.shape)
total_missing = count_missing_values.sum()
missing_percentage = (total_missing/total_no_of_cells)*100
print(missing_percentage)
# Out:
# 24.85847694188906

# %%
# handling missing values by removing the rows 
# which has missing value in any coloumn
data = df # make copy of the original dataframe

data.dropna()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
#  Looks like all the data has been removed.

# %%
# dropping data using columns
columns_with_missing_values_dropped = data.dropna(axis=1)
columns_with_missing_values_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# 0              1            39   0  ...                  0          None
# 1              1             5   0  ...                  0          None
# 2              1            -3   0  ...                  0          None
# 3              1             0   0  ...                  0          None
# 4              1             0   0  ...                  0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# ...

# %%
print("No of columns of Original data:" ,data.shape[1])
print("No of columns of dropped data:", columns_with_missing_values_dropped.shape[1])
# Out:
# No of columns of Original data: 102
# No of columns of dropped data: 41

# %%
subset_of_data = data.loc[:,'EPA':'Season'].head()
subset_of_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
# Replace missing values with zero
subset_of_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
# replacing missing values with the value 
# which is just after the missing value in its column and 
# all other missing values will be replaced with zero

subset_of_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %% [markdown]
# SCALING & NORMALIZATION

# %%
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## Difference between scaling and normalization
#
# In scaling, the range of the data changes
# But in normalization the shape of the distribution of data changes.

# %%
# let us generate random data points from exponential distribution
random_data = np.random.exponential(size=1000)
normalized_data = stats.boxcox(random_data)

fig, ax = plt.subplots(1,2, figsize=(15,8))
sns.histplot(random_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Orginal data")
sns.histplot(normalized_data[0],ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized data")
plt.show()

# %%
import datetime

# %%
# reading data
landslides_data = pd.read_csv("C:/Users/tiwar/Downloads/catalog.csv")
landslides_data.head()
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
# 4  61  4/15/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
# 4       Kentucky        6903         Pikeville   5.66542  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# ...

# %%
landslides_data['date'].head()
# Out:
# 0     3/2/07
# 1    3/22/07
# 2     4/6/07
# 3    4/14/07
# 4    4/15/07
# Name: date, dtype: object

# %%
landslides_data['date_parsed'] = pd.to_datetime(landslides_data['date'],format="%m/%d/%y")
landslides_data['date_parsed'].head()
# Out:
# 0   2007-03-02
# 1   2007-03-22
# 2   2007-04-06
# 3   2007-04-14
# 4   2007-04-15
# Name: date_parsed, dtype: datetime64[ns]

# %%
# selecting the day of month
day_of_month = landslides_data['date_parsed'].dt.day
day_of_month.head()
# Out:
# 0     2.0
# 1    22.0
# 2     6.0
# 3    14.0
# 4    15.0
# Name: date_parsed, dtype: float64

# %%
#fetching record of row no 6
record = landslides_data.loc[5]
record.head()
# Out:
# id                           64
# date                    4/20/07
# time                        NaN
# continent_code              NaN
# country_name      United States
# Name: 5, dtype: object

# %%
day_of_month = day_of_month.dropna()
sns.histplot(day_of_month, kde=False, bins=31)
# Out:
# <AxesSubplot:xlabel='date_parsed', ylabel='Count'>

# %% [markdown]
# Handling Data Inconsistencies
